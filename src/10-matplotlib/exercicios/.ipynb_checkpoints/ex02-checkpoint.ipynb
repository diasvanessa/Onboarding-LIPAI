# %%
import pandas as pd 
import matplotlib.pyplot as plt

data = pd.read_csv('../../datasets/metrics.csv')
epochs = range(1, len(data) + 1)

plt.style.use('seaborn-v0_8')

# %% [markdown]
# Gere um gráfico semelhante ao de referência com as curvas de train_loss e val_loss
# e train_acc e val_acc. Use o eixo x como épocas. Use o arquivo de dados
# metrics.csv.

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

ax1.plot(epochs, df_metrics['train_loss'], label='Train Loss', color='#C44E52', linewidth=2.5)
ax1.plot(epochs, df_metrics['val_loss'], label='Val Loss', color='#4C72B0', linewidth=2.5, linestyle='--')
ax1.set_title('Curva de Perda (Loss)', fontsize=14, fontweight='bold')
ax1.set_xlabel('Épocas', fontsize=12)
ax1.set_ylabel('Loss', fontsize=12)
ax1.legend()
ax1.grid(True, linestyle='--', alpha=0.6)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 ax1.plot(epochs, df_metrics['train_loss'], label='Train Loss', color='#C44E52', linewidth=2.5)
#       2 ax1.plot(epochs, df_metrics['val_loss'], label='Val Loss', color='#4C72B0', linewidth=2.5, linestyle='--')
#       3 ax1.set_title('Curva de Perda (Loss)', fontsize=14, fontweight='bold')
#
# NameError: name 'ax1' is not defined
